# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritesh-Gawande/Machine-Learning-Code/blob/main/Diabetes_Logistic_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()

# %%
df = pd.read_csv('diabetes1.csv')

# %%
df

# %%
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.Pregnancies.unique()

# %%
sns.boxplot(df.Pregnancies)

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(df)

# %%
df.Insulin.unique()

# %%
# !pip install sweetviz
import sweetviz as sv

# %%
my_report = sv.analyze(df)
my_report.show_html()

# %%
df.isnull().sum()

# %%
sns.pairplot(df)

# %%
df.loc[df['Glucose']==0,'Glucose'] = np.median(df.Glucose)

# %%
df.loc[df['Insulin']==0,'Insulin'] = np.median(df.Insulin)

# %%
df.loc[df['SkinThickness']==0,'SkinThickness'] = np.median(df.SkinThickness)

# %%
df.loc[df['BMI']==0,'BMI'] = np.median(df.BMI)

# %%
plt.figure(figsize=(15, 6))
for i in df.columns:
  sns.histplot(df[i])

# %%
df.loc[df.BloodPressure<40,'BloodPressure']=40

# %%
df.corr()

# %% [markdown]
# Modeling

# %%
x = df.drop('Outcome',axis=1)
y= df.Outcome

# %%
y.value_counts()

# %%
x.value_counts()

# %%
from sklearn.model_selection import train_test_split
x_train_raw,x_test_raw,y_train,y_test = train_test_split(x,y,train_size=0.2,random_state=42)

# %%
from re import X
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scal = scaler.fit_transform(x_train_raw)
X_test = scaler.transform(x_test_raw)

# %%
x_scal

# %%
x_train = pd.DataFrame(data=x_scal,columns=x_train_raw.columns)

# %%
x_train

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train,y_train)

# %%
x_test = pd.DataFrame(data=X_test,columns=x_test_raw.columns)
y_pred = model.predict(x_test)

# %%
X1 = pd.DataFrame()
X1[0] = y_pred
X1[1] = y_test.values
X1[2] = y_test.values - y_pred

# %%
X1

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, f1_score
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(accuracy_score(y_test,y_pred))
print(f1_score(y_test,y_pred))
