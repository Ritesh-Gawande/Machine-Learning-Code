# %% [markdown]
# <a href="https://colab.research.google.com/github/Ritesh-Gawande/Machine-Learning-Code/blob/main/insurance_binary_classification_logistic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
up = files.upload()
# Out:
#      <input type="file" id="files-6f14bd19-6389-4428-97ac-6da7b11061e7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6f14bd19-6389-4428-97ac-6da7b11061e7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age,df.bought_insurance)

# %%
x=df.drop("bought_insurance",axis=1)
y=df.bought_insurance

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2)

# %%
x_test
# Out:
#     age
# 3    52
# 8    62
# 5    56
# 10   18
# 4    46
# 13   29

# %%
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = LR.predict(x_test)

# %%
y_pred
# Out:
# array([1, 1, 1, 0, 1, 0])

# %%
Pre = pd.DataFrame({"Actual":y_test,"Predicted":y_pred})
Pre
# Out:
#     Actual  Predicted
# 3        0          1
# 8        1          1
# 5        1          1
# 10       0          0
# 4        1          1
# 13       0          0

# %%
LR.score(x_test,y_test)
# Out:
# 0.8333333333333334

# %%
LR.predict_proba(x_test)
# Out:
# array([[0.09358171, 0.90641829],
#        [0.02305834, 0.97694166],
#        [0.05411757, 0.94588243],
#        [0.93973397, 0.06026603],
#        [0.20017103, 0.79982897],
#        [0.75464129, 0.24535871]])

# %%
LR.predict([[2]])
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm1 = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test,y_pred)
cm,cm1
# Out:
# (array([[2, 1],
#         [0, 3]]),
#  0.8333333333333334)
